# %% [markdown]
# <a href="https://colab.research.google.com/github/Pronathan/na3a-programmering/blob/main/0824_m%C3%A5ndag_variabler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namn = "Jonathan"
ålder = 17
är_vinnare = True
net_worth = 3.1415926535897932384626

ålder += 1


print(namn)
print(ålder)
print(är_vinnare)
print(net_worth)
print(type(namn))
print(type(ålder))
print(type(är_vinnare))
print(type(net_worth))
# Out:
# Jonathan
# 18
# True
# 3.141592653589793
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>
