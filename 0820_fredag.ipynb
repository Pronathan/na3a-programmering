# %% [markdown]
# <a href="https://colab.research.google.com/github/Pronathan/na3a-programmering/blob/main/0820_fredag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello man")
namn = input("Skriv ditt namn: ")
print("Hej, " , namn)
disc = input ("Använder du främst discar från Discmania, Latitude 64 eller Innova")
print("Åå, det är ett bra märke :)" + disc)
# Out:
# Hello man
# Skriv ditt namn: Jonathan
# Hej,  Jonathan
# Använder du främst discar från Discmania, Latitude 64 eller InnovaLatitude 64
# Åå, det är ett bra märke :)Latitude 64
