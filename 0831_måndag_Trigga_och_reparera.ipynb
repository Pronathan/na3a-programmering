# %% [markdown]
# <a href="https://colab.research.google.com/github/Pronathan/na3a-programmering/blob/main/0831_m%C3%A5ndag_Trigga_och_reparera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "discmania"
print(x)

print(x + "10")

print("kingen" + x +"10")

int("Jonathan")
# Out:
# discmania
# discmania10
# kingendiscmania10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2597/999198051.py in <cell line: 0>()
#       6 print("kingen" + x +"10")
#       7
# ----> 8 int("Jonathan")
#
# ValueError: invalid literal for int() with base 10: 'Jonathan'
