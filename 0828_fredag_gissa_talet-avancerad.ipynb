# %% [markdown]
# <a href="https://colab.research.google.com/github/Pronathan/na3a-programmering/blob/main/0828_fredag_gissa_talet-avancerad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
while True:
  print (f"Hej, välkommen till Gissningsspelet - computatrum")

  inloggad = input(f"Vill du logga in i spelet? (ja/nej): ").strip().lower()
  if inloggad == "nej":
    print("Du måste vara inloggad för att kunna spela!")
    print("Spelet avslutas")
    break
  else:
    användarnamn = input("Användarnamn: ")
    lösenord = (input("Lösenord: "))
    print(f"Du är nu inloggad som {användarnamn}" )
    print(f"Ditt lösenord är ****")


  datortanke = random.randint(1,10)

  if inloggad.lower() == "ja":
      print("Laddar spelet....")
      print("....")
      print("....")

  while True:
    användargissning = int(input(f"Vilket tal mellan 1-10 tror du att datorn tänker på? "))
    if användargissning > 10 or användargissning < 1:
      print("Ogiltig gissning!")

    if datortanke == användargissning:
      print (f"Snyggt, du gissade {användargissning} och dator tänkte på {datortanke}. Du gissade alltså rätt!")
      svar = input(f"Vill du fortsätta spela? (ja/nej): ")

      if svar.lower() == "ja":
        print("Fortsätter...\n")
      else:
        print("Spel avslutas.")
        break

    else:
      print(f"Tyvärr, det var inte vad datorn tänlkte på den här gången! Du gissade på {användargissning}, och datorn tänkte på {datortanke}. Försök igen!")
# Out:
# Hej, välkommen till Gissningsspelet - computatrum
# Vill du logga in i spelet? (ja/nej): nej
# Du måste vara inloggad för att kunna spela!
# Spelet avslutas
