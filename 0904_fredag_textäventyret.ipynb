# %% [markdown]
# <a href="https://colab.research.google.com/github/Pronathan/na3a-programmering/blob/main/0904_fredag_text%C3%A4ventyret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hej, kul att du har hittat hit!")
print("Det här programmet är tänkt att kunna vara en medhjälpare till dig ute på discgolf banan.")
print("Genom att svara på ett par frågor, kan jag ge dig tips som förhoppningsvis kan hjälpa dig att förbättra dit score")

start = input("Vill du starta programmet? Ja eller nej? ")
if start.lower() == "ja":
  print("Programmet laddar...")
else:
  print("Programmet avslutas...")

if start.lower() == "ja":
  namn = input("Vad heter du? ")
  print(f"Hej {namn}!")
  erfarenhet = int(input("Hur länge har du spelat discgolf (antal månader)? "))
  if erfarenhet > 6:
    print("Okej, du har alltså en del erfarenhet. Då klarar du av att hantera lite svårare discar")
  else:
    print("Okej, du är alltså rätt ny på sporten. Du behöver discar som är lite enklare att kasta")

  kastlängd = int(input("Hur långt kan du kasta en vanlig kastputter (antal meter)? "))
  if kastlängd <= 50:
    print("Du verkar vara en nybörjare")
    hänt = input("Kastar du med vänster eller höger arm? Svara höger/vänster: ")
    if hänt.lower() == "höger":
      kast = input("Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: ")
      typ = input("Vill du kasta en forehand eller en backhand? ")
      if typ.lower() == "backhand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Innova Gator på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Pioneer på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Innova Firebird på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Innova Star Wraith på en högerhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Innova Star Wraith på en högerhänt backhand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Innova Aviar på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Innova Teebird på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Innova Teebird på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Innova Star Wraith på en högerhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Innova Star Wraith på en högerhänt backhand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Innova Leopard3 på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Innova Leopard3 på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Innova Roadrunner på en högerhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Innova Roadrunner på en högerhänt backhand")
      elif typ.lower() == "forehand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Jade på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Jade på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Sapphire på en högerhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Sapphire på en högerhänt forehand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Fuse på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Opto Air Fuse på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Sapphire på en högerhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Sapphire på en högerhänt forehand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Pearl på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Fuse på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en högerhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Diamond på en högerhänt forehand")
    # här börjar logiken för vänsterhänta
    elif hänt.lower() == "vänster":
      kast = input("Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: ")
      typ = input("Vill du kasta en forehand eller en backhand? ")
      if typ.lower() == "backhand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Pearl på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Jade på en vänsterhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Jade på en vänsterhänt backhand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Pearl på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Jade på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Sapphire på en vänsterhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Sapphire på en vänsterhänt backhand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Jade på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Sapphire på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Sapphire på en vänsterhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Sapphire på en vänsterhänt backhand")
      elif typ.lower() == "forehand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Pearl på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Jade på en vänsterhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Jade på en vänsterhänt forehand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Pearl på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Jade på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Sapphire på en vänsterhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Sapphire på en vänsterhänt forehand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Diamond på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Jade på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Sapphire på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Sapphire på en vänsterhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Sapphire på en vänsterhänt forehand")
        # här börjar logiken för amatör
  elif kastlängd > 50 and kastlängd < 80:
    print("Du verkar vara en amatör")
    hänt = input("Kastar du med vänster eller höger arm? Svara höger/vänster: ")
    if hänt.lower() == "höger":
      kast = input("Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: ")
      typ = input("Vill du kasta en forehand eller en backhand? ")
      if typ.lower() == "backhand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz OS på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania Method på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Innova Teebird på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Innova Thunderbird på en högerhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Innova Thunderbird på en högerhänt backhand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Innova Mako3 på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 River på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Lots på en högerhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Kastaplast Lots på en högerhänt backhand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Svea på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Saint på en högerhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Saint på en högerhänt backhand")
      elif typ.lower() == "forehand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Svea på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Saint på en högerhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Saint på en högerhänt forehand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Innova Mako3 på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 River på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Lots på en högerhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Kastaplast Lots på en högerhänt forehand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz OS på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania Method på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Innova Teebird på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Innova Thunderbird på en högerhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Innova Thunderbird på en högerhänt forehand")
    # här börjar logiken för vänsterhänta
    elif hänt.lower() == "vänster":
      kast = input("Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: ")
      typ = input("Vill du kasta en forehand eller en backhand? ")
      if typ.lower() == "backhand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Svea på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Saint på en vänsterhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Saint på en vänsterhänt backhand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Innova Mako3 på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 River på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Lots på en vänsterhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Kastaplast Lots på en vänsterhänt backhand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz OS på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania Method på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Innova Teebird på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Innova Thunderbird på en vänsterhänt backhand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Innova Thunderbird på en vänsterhänt backhand")
      elif typ.lower() == "forehand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz OS på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania Method på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Innova Teebird på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Innova Thunderbird på en vänsterhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Innova Thunderbird på en vänsterhänt forehand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Innova Mako3 på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 River på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Lots på en vänsterhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Kastaplast Lots på en vänsterhänt forehand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Svea på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Latitude 64 Saint på en vänsterhänt forehand")
          elif längd >= 120:
            print("Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Latitude 64 Saint på en vänsterhänt forehand")
        # här börjar logiken för duktig amatör
  elif kastlängd > 80 and kastlängd < 100:
    print("Du verkar vara en duktig amatör")
    hänt = input("Kastar du med vänster eller höger arm? Svara höger/vänster: ")
    if hänt.lower() == "höger":
      kast = input("Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: ")
      typ = input("Vill du kasta en forehand eller en backhand? ")
      if typ.lower() == "backhand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Method på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania MD4 på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania FD2 på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania C-Line MD5 på en högerhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania C-Line FD3 på en högerhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Gannon Buhr Signature Series Q-Line Premier Cloud Breaker på en högerhänt backhand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania FD på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 C-Line på en högerhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier FD på en högerhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier DD3 på en högerhänt backhand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Svea på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin Neo på en högerhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Neo Essence på en högerhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD S-Line på en högerhänt backhand")
      elif typ.lower() == "forehand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Svea på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence på en högerhänt forehand")
            print("Jag skulle rekomendera dig att kasta en Discmania Essence Neo på en högerhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania TD S-Line på en högerhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD S-Line på en högerhänt forehand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania FD på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 C-Line på en högerhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier MD3 på en högerhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier DD3 på en högerhänt forehand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Method på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania MD4 på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania FD2 på en högerhänt forehand")
            print("Jag skulle rekomendera dig att kasta en Discraft CryZtal FLX Zone på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD5 C-Line på en högerhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania MD5 C-Line på en högerhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier Cloud Breaker – Gannon Buhr Signature Series på en högerhänt forehand")
    # här börjar logiken för vänsterhänta
    elif hänt.lower() == "vänster":
      kast = input("Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: ")
      typ = input("Vill du kasta en forehand eller en backhand? ")
      if typ.lower() == "backhand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Svea på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD5 C-Line på en vänsterhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania FD3 C-Line på en vänsterhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania PD C-Line på en vänsterhänt backhand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania FD på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 C-Line på en vänsterhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania FD S-Line på en vänsterhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD1 Horizon på en vänsterhänt backhand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Method på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania MD4 på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania FD2 på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin Neo på en vänsterhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence Neo på en vänsterhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD S-Line på en vänsterhänt backhand")
      elif typ.lower() == "forehand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Method på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania MD4 på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania FD2 på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania FD3 C-Line på en vänsterhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania PD C-Line på hyzer på en vänsterhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Cloud Breaker Premier på en vänsterhänt forehand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania FD på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania FD3 C-Line på en vänsterhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania PD C-Line på hyzer på en vänsterhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Cloud Breaker Premier på en vänsterhänt forehand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Kastaplast Svea på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence Neo på en vänsterhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania TD S-Line på en vänsterhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD S-Line på en vänsterhänt forehand")
        #här börjar logiken för elit nivå
  elif kastlängd > 100:
    print("Wow! Du är på elit nivå")
    hänt = input("Kastar du med vänster eller höger arm? Svara höger/vänster: ")
    if hänt.lower() == "höger":
      kast = input("Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: ")
      typ = input("Vill du kasta en forehand eller en backhand? ")
      if typ.lower() == "backhand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Razor Claw Tactic på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania P3x C-Line på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discraft ESP Zone på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania C-Line MD5 på en högerhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania C-Line FD3 på en högerhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Gannon Buhr Signature Series Q-Line Premier Cloud Breaker på en högerhänt backhand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania P1 D-Line på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania P2 Flex 2 på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania P2 Flex 2 på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 C-Line på en högerhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier FD på en högerhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier DD3 på en högerhänt backhand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Logic Exo Soft på en högerhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania Link Exo Soft på en högerhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Logic på en högerhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin Neo på en högerhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Neo Essence på en högerhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD S-Line på en högerhänt backhand")
      elif typ.lower() == "forehand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania P1 D-Line på anhyzer på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania Logic på turnover på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin Neo på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence Neo på en högerhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania TD S-Line på en högerhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD S-Line på en högerhänt forehand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania P1 D-Line på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania P2 Flex 2 på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania P1 D-Line på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 C-Line på en högerhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier MD3 på en högerhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier DD3 på en högerhänt forehand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Tactic – Razor Claw 4 på en högerhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania P3x C-Line på en högerhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discraft CryZtal FLX Zone på en högerhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD5 C-Line på en högerhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania MD5 C-Line på en högerhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier Cloud Breaker – Gannon Buhr Signature Series på en högerhänt forehand")
    # här börjar logiken för vänsterhänta
    elif hänt.lower() == "vänster":
      kast = input("Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: ")
      typ = input("Vill du kasta en forehand eller en backhand? ")
      if typ.lower() == "backhand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Notion på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania Notion på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin Neo på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin Neo på en vänsterhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence Neo på en vänsterhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD S-Line på en vänsterhänt backhand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania P1 D-Line på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania P2 Flex 2 på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania P1 D-Line på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 C-Line på en vänsterhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier MD3 på en vänsterhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Q-Line Premier DD3 på en vänsterhänt backhand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Razor Claw Tactic på en vänsterhänt backhand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania P3x C-Line på en vänsterhänt backhand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discraft ESP Zone på en vänsterhänt backhand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania MD5 C-Line på en vänsterhänt backhand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania FD3 C-Line på en vänsterhänt backhand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Cloud Breaker Premier på en vänsterhänt backhand")
      elif typ.lower() == "forehand":
        if kast.lower() == "vänster sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania Razor Claw Tactic på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discraft ESP Zone på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania MD5 C-Line på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania FD3 C-Line på en vänsterhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania PD C-Line på hyzer på en vänsterhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania Cloud Breaker Premier på en vänsterhänt forehand")
        if kast.lower() == "rakt":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discraft Buzzz SS på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania P2 Flex 2 på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania MD1 C-Line på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania FD C-Line på en vänsterhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania PD C-Line på en vänsterhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD3 Premier på en vänsterhänt forehand")
        if kast.lower() == "höger sväng":
          längd = int(input("Hur långt vill du kasta (meter)? "))
          if längd <= 50:
            print("Jag skulle rekomendera dig att kasta en Discmania P1 D-Line på anhyzer på en vänsterhänt forehand")
          elif längd > 50 and längd < 80:
            print("Jag skulle rekomendera dig att kasta en Discmania Logic på turnover på en vänsterhänt forehand")
          elif längd >= 80 and längd < 100:
            print("Jag skulle rekomendera dig att kasta en Discmania Origin Neo på en vänsterhänt forehand")
          elif längd >= 100 and längd < 120:
            print("Jag skulle rekomendera dig att kasta en Discmania Essence Neo på en vänsterhänt forehand")
          elif längd >= 120 and längd < 145:
            print("Jag skulle rekomendera dig att kasta en Discmania TD S-Line på en vänsterhänt forehand")
          elif längd >= 145:
            print("Jag skulle rekomendera dig att kasta en Discmania DD S-Line på en vänsterhänt forehand")
# Out:
# Hej, kul att du har hittat hit!
# Det här programmet är tänkt att kunna vara en medhjälpare till dig ute på discgolf banan.
# Genom att svara på ett par frågor, kan jag ge dig tips som förhoppningsvis kan hjälpa dig att förbättra dit score
# Vill du starta programmet? Ja eller nej? ja
# Programmet laddar...
# Vad heter du? bob
# Hej bob!
# Hur länge har du spelat discgolf (antal månader)? 22
# Okej, du har alltså en del erfarenhet. Då klarar du av att hantera lite svårare discar
# Hur långt kan du kasta en vanlig kastputter (antal meter)? 60
# Du verkar vara en amatör
# Kastar du med vänster eller höger arm? Svara höger/vänster: vänster
# Vilket kast önskar du nu utföra? Svara med vänster sväng, rakt eller höger sväng: höger sväng
# Vill du kasta en forehand eller en backhand? backhand
# Hur långt vill du kasta (meter)? 888
# Tyvärr kommer du inte kunna kasta så där långt eftersom din armspeed är för låg, men testa med en Innova Thunderbird på en vänsterhänt backhand
